# %%
# !pip install psycopg2

# %%
import pandas as pd
import psycopg2 as pg2

# %%
conn = pg2.connect(host='localhost', port=5432, dbname='demo', user='postgres', password='palmeiras1914')

# %%
cur = conn.cursor()

# %%
cur.execute('select * from ticket_flights')

# %%
conn.commit()

# %%
data = cur.fetchall()

# %%
cur.close()
conn.close()

# %%
data
# Out:
# [('0005432159776', 30625, 'Business', Decimal('42100.00')),
#  ('0005435212351', 30625, 'Business', Decimal('42100.00')),
#  ('0005435212386', 30625, 'Business', Decimal('42100.00')),
#  ('0005435212381', 30625, 'Business', Decimal('42100.00')),
#  ('0005432211370', 30625, 'Business', Decimal('42100.00')),
#  ('0005435212357', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212360', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212393', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212374', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212365', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212378', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212362', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212334', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212329', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212370', 30625, 'Comfort', Decimal('23900.00')),
#  ('0005435212328', 30625, 'Comfort', Decimal('23900.00')),
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                0      1         2         3
# 0  0005432159776  30625  Business  42100.00
# 1  0005435212351  30625  Business  42100.00
# 2  0005435212386  30625  Business  42100.00
# 3  0005435212381  30625  Business  42100.00
# 4  0005432211370  30625  Business  42100.00

# %%
col_name = ['ticket_no', 'flight_id', 'fare_conditions', 'amount']

# %%
df = pd.DataFrame(data, columns=col_name)

# %%
df.head()
# Out:
#        ticket_no  flight_id fare_conditions    amount
# 0  0005432159776      30625        Business  42100.00
# 1  0005435212351      30625        Business  42100.00
# 2  0005435212386      30625        Business  42100.00
# 3  0005435212381      30625        Business  42100.00
# 4  0005432211370      30625        Business  42100.00

# %% [markdown]
# ###  DVD RENTAL

# %%
conn = pg2.connect(host='localhost', port=5432, dbname='dvdrental', user='postgres', password='palmeiras1914')

# %%
cur = conn.cursor()

# %%
cur.execute('select * from actor')

# %%
conn.commit()

# %%
data = cur.fetchall()

# %%
colnames = [desc.name for desc in cur.description]

# %%
colnames
# Out:
# ['actor_id', 'first_name', 'last_name', 'last_update']

# %%
cur.close()
conn.close()

# %%
cur.description
# Out:
# (Column(name='actor_id', type_code=23),
#  Column(name='first_name', type_code=1043),
#  Column(name='last_name', type_code=1043),
#  Column(name='last_update', type_code=1114))

# %%
df = pd.DataFrame(data, columns=colnames)
df.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1         2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2         3         Ed         Chase 2013-05-26 14:47:57.620
# 3         4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4         5     Johnny  Lollobrigida 2013-05-26 14:47:57.620
