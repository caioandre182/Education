# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
renda = pd.read_csv('previsao_de_renda.csv')
renda.head(2)
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
#
#    qtd_filhos   tipo_renda    educacao estado_civil tipo_residencia  idade  \
# 0           1  Assalariado  Secundário       Casado            Casa     36
# 1           0   Empresário  Secundário       Casado            Casa     42
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# 1       0.860274                    2.0  False  6096.14

# %%
renda['data_ref'] = pd.to_datetime(renda['data_ref'])

# %%
#Posse_de_veiculo
ax = sns.countplot(x='data_ref', hue='posse_de_veiculo', data=renda)
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Educação
sns.set_style('whitegrid')
ax = sns.countplot(x='data_ref', hue='educacao', data=renda, color='viridis', palette='muted')
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ##### A partir do mês de setembro (09) existe uma queda de pessoas no secundário, onde a média era na casa do 690, e passa a ser aproximadamente 500. E coincidentemente existe um salto de pessoas no Superior Completo, onde a média era por volta de 250, e passa a ser aproximadamente 410.

# %%
#Tipo_renda
sns.set_style('whitegrid')
ax = sns.countplot(x='data_ref', hue='tipo_renda', data=renda, color='viridis', palette='muted')
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Sexo
sns.set_style('whitegrid')
ax = sns.countplot(x='data_ref', hue='sexo', data=renda, color='viridis', palette='muted')
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Posse_de_imovel
sns.set_style('whitegrid')
ax = sns.countplot(x='data_ref', hue='posse_de_imovel', data=renda, color='viridis', palette='muted')
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Estado_civil
sns.set_style('whitegrid')
ax = sns.countplot(x='data_ref', hue='estado_civil', data=renda, color='viridis', palette='muted')
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Tipo_residencia
sns.set_style('whitegrid')
ax = sns.countplot(x='data_ref', hue='tipo_residencia', data=renda, color='viridis', palette='muted')
ax.figure.set_size_inches(12, 8)
tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
#Posse_de_veiculo
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_veiculo',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
#Educação
ax = sns.pointplot(x="data_ref", y="renda", hue = 'educacao',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
#Tipo_renda
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_renda',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
#Sexo
ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
#Posse_de_imovel
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_imovel',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
#Estado_civil
ax = sns.pointplot(x="data_ref", y="renda", hue = 'estado_civil',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
#Tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_residencia',
                   data=renda, dodge=True, ci = 95)

ax.figure.set_size_inches(12, 8)
plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=0)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %% [markdown]
# ##### As variáveis sexo e posse_de_veiculo são as mais estáveis, o restante das variáveis qualitativas se mostraram instáveis em algumas categorias, o que dificultaria para o modelo ter uma acurácia boa.
